# %% [markdown]
# <a href="https://colab.research.google.com/github/varshithagopu12/6220/blob/main/6220.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret==3.0.0

# %%
from pycaret.utils import version
version()
# Out:
# '3.0.0'

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
import pandas as pd
plt.rcParams['figure.figsize'] = (7,5)

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
print("Pandas version: ", pd.__version__)
print("Seaborn version: ", sns.__version__)
# Out:
# Pandas version:  1.5.3
# Seaborn version:  0.12.2

# %%
import pandas as pd

# %%
csv_url = 'https://raw.githubusercontent.com/varshithagopu12/6220/main/TESLAO.csv'

# %%
df = pd.read_csv('https://raw.githubusercontent.com/varshithagopu12/6220/main/TESLAO.csv')

df.head(20)
# Out:
#           Date      Open      High       Low     Close  Adj Close     Volume  \
# 0   29-06-2010  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1   30-06-2010  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2   01-07-2010  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 3   02-07-2010  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 4   06-07-2010  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
# 5   07-07-2010  1.093333  1.108667  0.998667  1.053333   1.053333  103825500
# 6   08-07-2010  1.076000  1.168000  1.038000  1.164000   1.164000  115671000
# 7   09-07-2010  1.172000  1.193333  1.103333  1.160000   1.160000   60759000
# 8   12-07-2010  1.196667  1.204667  1.133333  1.136667   1.136667   33037500
# 9   13-07-2010  1.159333  1.242667  1.126667  1.209333   1.209333   40201500
# 10  14-07-2010  1.196000  1.343333  1.184000  1.322667   1.322667   62928000
# ...

# %%
df.head(20)
# Out:
#           Date      Open      High       Low     Close  Adj Close     Volume  \
# 0   29-06-2010  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 1   30-06-2010  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2   01-07-2010  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 3   02-07-2010  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 4   06-07-2010  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
# 5   07-07-2010  1.093333  1.108667  0.998667  1.053333   1.053333  103825500
# 6   08-07-2010  1.076000  1.168000  1.038000  1.164000   1.164000  115671000
# 7   09-07-2010  1.172000  1.193333  1.103333  1.160000   1.160000   60759000
# 8   12-07-2010  1.196667  1.204667  1.133333  1.136667   1.136667   33037500
# 9   13-07-2010  1.159333  1.242667  1.126667  1.209333   1.209333   40201500
# 10  14-07-2010  1.196000  1.343333  1.184000  1.322667   1.322667   62928000
# ...

# %%
len(df.index)
# Out:
# 99

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       99 non-null     object
#  1   Open       99 non-null     float64
#  2   High       99 non-null     float64
#  3   Low        99 non-null     float64
#  4   Close      99 non-null     float64
#  5   Adj Close  99 non-null     float64
#  6   Volume     99 non-null     int64
#  7   high/low   99 non-null     int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 6.3+ KB

# %%
print("Number of duplicated rows is: ", df.duplicated().sum())
# Out:
# Number of duplicated rows is:  0

# %%
print("Number of rows with NaNs is: ", df.isna().any(axis=1).sum())
# Out:
# Number of rows with NaNs is:  0

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Select numerical columns
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
data = df[numerical_columns]

# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# Perform PCA
pca = PCA()
principal_components = pca.fit_transform(scaled_data)

# Calculate explained variance
explained_variance = pca.explained_variance_ratio_

# Plot the scree plot
plt.plot(range(1, len(explained_variance) + 1), explained_variance, marker='o')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.show()

# %% [markdown]
# EDA

# %%
# Create a pair plot
sns.pairplot(df, hue='high/low')  # You can customize the diag_kind parameter based on your preference
plt.show()

# %%
y =df['high/low']
y.value_counts().plot(kind='pie')
plt.ylabel('')
plt.show()

# %%
X = df.drop(columns=['Volume'])
X.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close  high/low
# 0  29-06-2010  1.266667  1.666667  1.169333  1.592667   1.592667         1
# 1  30-06-2010  1.719333  2.028000  1.553333  1.588667   1.588667         1
# 2  01-07-2010  1.666667  1.728000  1.351333  1.464000   1.464000         1
# 3  02-07-2010  1.533333  1.540000  1.247333  1.280000   1.280000         1
# 4  06-07-2010  1.333333  1.333333  1.055333  1.074000   1.074000         0
# 5  07-07-2010  1.093333  1.108667  0.998667  1.053333   1.053333         1
# 6  08-07-2010  1.076000  1.168000  1.038000  1.164000   1.164000         1
# 7  09-07-2010  1.172000  1.193333  1.103333  1.160000   1.160000         1
# 8  12-07-2010  1.196667  1.204667  1.133333  1.136667   1.136667         1
# 9  13-07-2010  1.159333  1.242667  1.126667  1.209333   1.209333         1

# %%
X.describe().transpose()
# Out:
#            count      mean       std       min       25%       50%       75%  \
# Open        99.0  1.395488  0.161567  1.076000  1.326334  1.377333  1.412667
# High        99.0  1.438761  0.189286  1.108667  1.348666  1.398000  1.456667
# Low         99.0  1.351340  0.154789  0.998667  1.300000  1.350667  1.380666
# Close       99.0  1.393468  0.170051  1.053333  1.324667  1.369333  1.410333
# Adj Close   99.0  1.393468  0.170051  1.053333  1.324667  1.369333  1.410333
# high/low    99.0  0.555556  0.499433  0.000000  0.000000  1.000000  1.000000
#
#                 max
# Open       2.066667
# High       2.196000
# Low        2.014667
# Close      2.053333
# Adj Close  2.053333
# high/low   1.000000

# %% [markdown]
# Standardize data

# %%
from sklearn.preprocessing import StandardScaler

# Assuming X is your DataFrame
numeric_columns = X.select_dtypes(include=['number']).columns

# Standardize only numeric columns
X[numeric_columns] = StandardScaler().fit_transform(X[numeric_columns])


# Now, X contains standardized values for numeric columns
X.head(10)
# Out:
#          Date      Open      High       Low     Close  Adj Close  high/low
# 0  29-06-2010 -0.801382  1.210156 -1.181822  1.177368   1.177368  0.894427
# 1  30-06-2010  2.014602  3.128795  1.311597  1.153726   1.153726  0.894427
# 2  01-07-2010  1.686972  1.535828 -0.000046  0.416880   0.416880  0.894427
# 3  02-07-2010  0.857517  0.537568 -0.675347 -0.670654  -0.670654  0.894427
# 4  06-07-2010 -0.386661 -0.559811 -1.922056 -1.888218  -1.888218 -1.118034
# 5  07-07-2010 -1.879674 -1.752763 -2.290004 -2.010371  -2.010371  0.894427
# 6  08-07-2010 -1.987500 -1.437711 -2.034604 -1.356273  -1.356273  0.894427
# 7  09-07-2010 -1.390295 -1.303195 -1.610379 -1.379915  -1.379915  0.894427
# 8  12-07-2010 -1.236845 -1.243013 -1.415580 -1.517824  -1.517824  0.894427
# 9  13-07-2010 -1.469095 -1.041237 -1.458865 -1.088331  -1.088331  0.894427

# %%
observations = list(df.index)
variables = list(df.columns)

# %%
ax = plt.figure(figsize=(15,10))
ax = sns.boxplot(data=X, orient="v", palette="Set2")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %%
# Use swarmplot() or stripplot to show the datapoints on top of the boxes:
#plt. figure()

ax = plt.figure(figsize=(15,10))
ax = sns.boxplot(data=X, orient="v", palette="Set2")
ax = sns.stripplot(data=X, color=".25")
ax.set_xticklabels(ax.get_xticklabels(),rotation=45);

# %%
fig1,ax1 = plt.subplots(figsize=(15,10))
ax = sns.heatmap(X.corr(), cmap='RdYlGn_r', linewidths=0.3, annot=True, cbar=False, square=True)
plt.yticks(rotation=0)
ax.tick_params(labelbottom=False,labeltop=True)
ax.set_xticklabels(ax.get_xticklabels(),rotation=0);

#X.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
#sns.clustermap(X.corr(), annot=True, fmt='.2f')

# %% [markdown]
# PC

# %%
pca = PCA()
Z = pca.fit_transform(X[numeric_columns])

# (High)->1,  (Low)->0

idx_High= np.where(y == 0)
idx_Low = np.where(y == 1)


plt. figure(figsize=(15,10))
plt.scatter(Z[idx_High,0], Z[idx_High,1], c='g', label='HIGH')
plt.scatter(Z[idx_Low,0], Z[idx_Low,1], c='r', label='LOW')

# %%
A = pca.components_.T
plt. figure(figsize=(8,4))

plt.scatter(A[:,0],A[:,1],c='r')
plt.xlabel('$A_1$')
plt.ylabel('$A_2$')
for label, x, y in zip(variables, A[:, 0], A[:, 1]):
  plt.annotate(label, xy=(x, y), xytext=(-2, 2), textcoords='offset points', ha='right', va='bottom')

# %%
plt. figure(figsize=(8,4))
plt.scatter(A[:, 0],A[:, 1], marker='o', c=A[:, 2], s=A[:, 3]*500, cmap=plt.get_cmap('Spectral'))
plt.xlabel('$A_1$')
plt.ylabel('$A_2$')
for label, x, y in zip(variables,A[:, 0],A[:, 1]):
  plt.annotate(label,xy=(x, y), xytext=(-20, 20),
      textcoords='offset points', ha='right', va='bottom',
      bbox=dict(boxstyle='round,pad=0.5', fc='blue', alpha=0.5),
      arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))

# %% [markdown]
# SCREE PLOT

# %%
#Eigenvalues
Lambda = pca.explained_variance_

#Scree plot
x = np.arange(len(Lambda)) + 1
plt. figure(figsize=(15,10))
plt.plot(x,Lambda/sum(Lambda), 'ro-', lw=3)
plt.xticks(x, [""+str(i) for i in x], rotation=0)
plt.xlabel('Number of components')
plt.ylabel('Explained variance')
Lambda
# Out:
# array([4.77511382e+00, 1.00802080e+00, 1.52052542e-01, 1.14007843e-01,
#        1.20294846e-02, 3.36470750e-34])

# %% [markdown]
# EXPLAINED VARIANCE

# %%
ell = pca.explained_variance_ratio_
ind = np.arange(len(ell))
plt. figure(figsize=(15,10))
plt.bar(ind, ell, align='center', alpha=0.5)
plt.plot(np.cumsum(ell))
plt.xlabel('Number of components')
plt.ylabel('Cumulative explained variance')
# Out:
# Text(0, 0.5, 'Cumulative explained variance')

# %% [markdown]
# BIPLOT

# %%
# 0,1 denote PC1 and PC2; change values for other PCs
A1 = A[:,0]
A2 = A[:,1]
Z1 = Z[:,0]
Z2 = Z[:,1]

plt. figure(figsize=(15,10))
plt.xlabel('Z1')
plt.ylabel('Z2')
for i in range(len(A1)):
# arrows project features as vectors onto PC axes
  plt.arrow(0, 0, A1[i]*max(Z1), A2[i]*max(Z2), color='k', width=0.0005, head_width=0.0025)
  plt.text(A1[i]*max(Z1)*1.2, A2[i]*max(Z2)*1.2,variables[i], color='k')

plt.scatter(Z[idx_Small,0], Z[idx_Small,1], c='r', label='Small')
plt.scatter(Z[idx_Medium,0], Z[idx_Medium,1], c='g', label='Medium')
plt.scatter(Z[idx_Large,0], Z[idx_Large,1], c='b', label='Large')

plt.legend(loc='upper left')
Z1
Z2
# Out:
# array([-0.94679636, -1.06209615, -0.98193024, -0.91803537,  1.16724542,
#        -0.77428031, -0.7936226 , -0.80628497, -0.80929532, -0.81971869,
#         1.15805908,  1.12769961,  1.12343946, -0.91015003, -0.8992366 ,
#         1.13162607,  1.12345811, -0.8964514 ,  1.11525542,  1.124522  ,
#         1.12956242, -0.87986034, -0.86866558, -0.88249234,  1.10643199,
#        -0.90906115,  1.11655083, -0.86252314,  1.15157968,  1.16038403,
#        -0.82885731, -0.80855804, -0.82172475, -0.83044269, -0.84360452,
#         1.16276355, -0.83765473,  1.17300459, -0.86323152, -0.84988717,
#         1.15421492, -0.86388693,  1.15348213, -0.86230933,  1.15610925,
#         1.13864593, -0.88648934, -0.88986309, -0.88193079,  1.12749468,
#         1.12516076, -0.87963932,  1.12796309, -0.89301717,  1.10566738,
#         1.08721842, -0.88700296, -0.88947582, -0.89250759,  1.13123016,
#         1.14938604, -0.86447977,  1.13262925, -0.89502576,  1.10407152,
# ...

# %% [markdown]
# PCA LIBRARY

# %%
# !pip install pca

# %%
from pca import pca
# Initialize and keep all PCs
model = pca()
# Fit transform
out = model.fit_transform(X[numeric_columns])
# Out:
# [pca] >Extracting column labels from dataframe.
# [pca] >Extracting row labels from dataframe.
# [pca] >The PCA reduction is performed to capture [95.0%] explained variance using the [6] columns of the input data.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Number of components is [2] that covers the [95.00%] explained variance.
# [pca] >The PCA reduction is performed on the [6] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Outlier detection using Hotelling T2 test with alpha=[0.05] and n_components=[2]
# [pca] >Multiple test correction applied for Hotelling T2 test: [fdr_bh]
# [pca] >Outlier detection using SPE/DmodX with n_std=[3]

# %%
out['PC']
# Out:
#          PC1       PC2
# 0   0.698144 -0.946796
# 1   3.882571 -1.062096
# 2   1.779125 -0.981930
# 3  -0.314614 -0.918035
# 4  -2.948374  1.167245
# ..       ...       ...
# 94  5.744041  0.937550
# 95  6.463159 -1.075332
# 96  7.403338 -1.102519
# 97  8.904285 -1.153266
# 98  8.113877  0.882123
#
# [99 rows x 2 columns]

# %%
from sklearn.decomposition import PCA
import numpy as np

# Assuming X is your data
pca = PCA()
Z = pca.fit_transform(X[numeric_columns])

# Check explained variance
explained_variance = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance)

# Set a threshold for cumulative explained variance
threshold = 0.95
num_components = np.argmax(cumulative_explained_variance >= threshold) + 1

# Alternatively, specify the number of components directly
# num_components = 10  # Choose your desired number of components

# Apply PCA with the selected number of components
pca = PCA(n_components=num_components)
Z = pca.fit_transform(X[numeric_columns])

# %%
model.scatter(label=True, legend=False)
# Out:
# [scatterd] >INFO> Create scatterplot
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# (<Figure size 2500x1500 with 1 Axes>,
#  <Axes: title={'center': '2 Principal Components explain [97.92%] of the variance'}, xlabel='PC1 (78.7% expl.var)', ylabel='PC2 (16.6% expl.var)'>)

# %%
A = out['loadings'].T
A
# Out:
#                 PC1       PC2
# Open       0.441093 -0.011375
# High       0.445615 -0.042140
# Low        0.444653 -0.001071
# Close      0.451829 -0.005365
# Adj Close  0.451829 -0.005365
# high/low  -0.029149 -0.999018

# %%
sns.scatterplot(data=A, x="PC1", y="PC2")
plt.xlabel('$A_1$')
plt.ylabel('$A_2$')
for i in range(A.shape[0]):
 plt.text(x=A.PC1[i]+0.02,y=A.PC2[i]+0.02, s=variables[i],
          fontdict=dict(color='red',size=10),
          bbox=dict(facecolor='yellow',alpha=0.5))

# %%
VR = out['variance_ratio']
x = np.arange(len(VR)) + 1
plt.plot(x, VR, 'ro-', lw=3)
plt.xticks(x, [""+str(i) for i in x], rotation=0)
plt.xlabel('Number of components')
plt.ylabel('Explained variance')
plt.show()

# %%
model.plot();

# %%
model.biplot(label=False, legend=False, color_arrow='k')
# Out:
# [scatterd] >INFO> Create scatterplot
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# [pca] >Plot PC1 vs PC2 with loadings.
# (<Figure size 2500x1500 with 1 Axes>,
#  <Axes: title={'center': '2 Principal Components explain [97.92%] of the variance'}, xlabel='PC1 (78.7% expl.var)', ylabel='PC2 (16.6% expl.var)'>)

# %% [markdown]
# Classification using Pycaret

# %%
#Run the below code in your notebook to check the installed version
from pycaret.utils import version
version()
# Out:
# '3.0.0'

# %%
data = df.sample(frac=0.9, random_state=786)
data_unseen = df.drop(data.index)
#dr = df.drop(columns=['id'])

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (89, 8)
# Unseen Data For Predictions: (10, 8)

# %%
from pycaret.classification import *
clf = setup(data=data, target='high/low', train_size=0.7, session_id=123)
# Out:
# <style type="text/css">
# #T_70bfd_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_70bfd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70bfd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_70bfd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70bfd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_70bfd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_70bfd_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_70bfd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_70bfd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_70bfd_row1_col1" class="data row1 col1" >high/low</td>
#     </tr>
#     <tr>
#       <th id="T_70bfd_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
#show the best model and their statistics
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_ec029 th {
#   text-align: left;
# }
# ...

# %%
best_model
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        random_state=123, splitter='best')

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_76db6_row10_col0, #T_76db6_row10_col1, #T_76db6_row10_col2, #T_76db6_row10_col3, #T_76db6_row10_col4, #T_76db6_row10_col5, #T_76db6_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_76db6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76db6_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_76db6_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_76db6_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_76db6_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_76db6_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_76db6_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_76db6_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_lr=tune_model(lr)
# Out:
# <style type="text/css">
# #T_126fd_row10_col0, #T_126fd_row10_col1, #T_126fd_row10_col2, #T_126fd_row10_col3, #T_126fd_row10_col4, #T_126fd_row10_col5, #T_126fd_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_126fd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_126fd_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_126fd_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_126fd_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_126fd_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_126fd_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_126fd_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_126fd_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_lr
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
evaluate_model(tuned_lr)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# Creating KNN model

# %%
knn = create_model('knn')
# Out:
# <style type="text/css">
# #T_45f7e_row10_col0, #T_45f7e_row10_col1, #T_45f7e_row10_col2, #T_45f7e_row10_col3, #T_45f7e_row10_col4, #T_45f7e_row10_col5, #T_45f7e_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_45f7e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_45f7e_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_45f7e_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_45f7e_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_45f7e_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_45f7e_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_45f7e_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_45f7e_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_knn = tune_model(knn)
# Out:
# <style type="text/css">
# #T_7f910_row10_col0, #T_7f910_row10_col1, #T_7f910_row10_col2, #T_7f910_row10_col3, #T_7f910_row10_col4, #T_7f910_row10_col5, #T_7f910_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_7f910" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f910_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_7f910_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_7f910_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_7f910_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_7f910_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_7f910_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_7f910_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=49, p=2,
#                      weights='uniform')

# %%
evaluate_model(tuned_knn)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
qda=create_model('qda')
# Out:
# <style type="text/css">
# #T_dcdcd_row10_col0, #T_dcdcd_row10_col1, #T_dcdcd_row10_col2, #T_dcdcd_row10_col3, #T_dcdcd_row10_col4, #T_dcdcd_row10_col5, #T_dcdcd_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_dcdcd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcdcd_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_dcdcd_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_dcdcd_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_dcdcd_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_dcdcd_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_dcdcd_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_dcdcd_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_qda=tune_model(qda)
# Out:
# <style type="text/css">
# #T_c9b43_row10_col0, #T_c9b43_row10_col1, #T_c9b43_row10_col2, #T_c9b43_row10_col3, #T_c9b43_row10_col4, #T_c9b43_row10_col5, #T_c9b43_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_c9b43" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9b43_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_c9b43_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_c9b43_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_c9b43_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_c9b43_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_c9b43_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_c9b43_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_qda
# Out:
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.98,
#                               store_covariance=False, tol=0.0001)

# %%
evaluate_model(tuned_qda)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# !pip install statsmodels --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 28.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.14.0
#     Uninstalling statsmodels-0.14.0:
#       Successfully uninstalled statsmodels-0.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# ...

# %% [markdown]
# Classification + PCA

# %%
clf_pca = setup(data=data, target='high/low', train_size=0.7, session_id=123, normalize = True, pca = True, pca_components = 2)
# Out:
# <style type="text/css">
# #T_9ceb5_row9_col1, #T_9ceb5_row15_col1, #T_9ceb5_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9ceb5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ceb5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9ceb5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ceb5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ceb5_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9ceb5_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_9ceb5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9ceb5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9ceb5_row1_col1" class="data row1 col1" >high/low</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# Models comparision

# %%
#show the best model and their statistics
best_model_pca = compare_models()
# Out:
# <style type="text/css">
# #T_3b8e3 th {
#   text-align: left;
# }
# ...

# %%
best_model_pca
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator='deprecated',
#                    estimator=None, learning_rate=1.0, n_estimators=50,
#                    random_state=123)

# %%
# Tune hyperparameters with scikit-learn (default)
tuned_best_model_pca = tune_model(best_model_pca)
# Out:
# <style type="text/css">
# #T_9a9a2_row10_col0, #T_9a9a2_row10_col1, #T_9a9a2_row10_col2, #T_9a9a2_row10_col3, #T_9a9a2_row10_col4, #T_9a9a2_row10_col5, #T_9a9a2_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9a9a2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a9a2_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9a9a2_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9a9a2_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9a9a2_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9a9a2_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9a9a2_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9a9a2_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %% [markdown]
# Model evaluation

# %%
evaluate_model(tuned_best_model_pca)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
lr_pca = create_model('lr')
# Out:
# <style type="text/css">
# #T_93a40_row10_col0, #T_93a40_row10_col1, #T_93a40_row10_col2, #T_93a40_row10_col3, #T_93a40_row10_col4, #T_93a40_row10_col5, #T_93a40_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_93a40" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93a40_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_93a40_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_93a40_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_93a40_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_93a40_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_93a40_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_93a40_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_lr_pca = tune_model(lr_pca)
# Out:
# <style type="text/css">
# #T_1ca53_row10_col0, #T_1ca53_row10_col1, #T_1ca53_row10_col2, #T_1ca53_row10_col3, #T_1ca53_row10_col4, #T_1ca53_row10_col5, #T_1ca53_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_1ca53" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ca53_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_1ca53_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_1ca53_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_1ca53_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_1ca53_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_1ca53_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_1ca53_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_lr_pca
# Out:
# LogisticRegression(C=0.056, class_weight={}, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
evaluate_model(tuned_lr_pca)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# Creating K-nearest neighbour Model

# %%
knn_pca = create_model('knn')
# Out:
# <style type="text/css">
# #T_4ce7f_row10_col0, #T_4ce7f_row10_col1, #T_4ce7f_row10_col2, #T_4ce7f_row10_col3, #T_4ce7f_row10_col4, #T_4ce7f_row10_col5, #T_4ce7f_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_4ce7f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ce7f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_4ce7f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_4ce7f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_4ce7f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_4ce7f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_4ce7f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_4ce7f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_knn_pca = tune_model(knn_pca)
# Out:
# <style type="text/css">
# #T_14037_row10_col0, #T_14037_row10_col1, #T_14037_row10_col2, #T_14037_row10_col3, #T_14037_row10_col4, #T_14037_row10_col5, #T_14037_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_14037" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14037_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_14037_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_14037_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_14037_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_14037_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_14037_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_14037_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_knn_pca
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='euclidean',
#                      metric_params=None, n_jobs=-1, n_neighbors=12, p=2,
#                      weights='distance')

# %%
evaluate_model(tuned_knn_pca)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# Creating Quadratic Discriminant Analysis Model

# %%
qda_pca = create_model('qda')
# Out:
# <style type="text/css">
# #T_f417f_row10_col0, #T_f417f_row10_col1, #T_f417f_row10_col2, #T_f417f_row10_col3, #T_f417f_row10_col4, #T_f417f_row10_col5, #T_f417f_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f417f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f417f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f417f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f417f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f417f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f417f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f417f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f417f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_qda_pca = tune_model(qda_pca)
# Out:
# <style type="text/css">
# #T_bd7a2_row10_col0, #T_bd7a2_row10_col1, #T_bd7a2_row10_col2, #T_bd7a2_row10_col3, #T_bd7a2_row10_col4, #T_bd7a2_row10_col5, #T_bd7a2_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_bd7a2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd7a2_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_bd7a2_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_bd7a2_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_bd7a2_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_bd7a2_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_bd7a2_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_bd7a2_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_qda_pca
# Out:
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.96,
#                               store_covariance=False, tol=0.0001)

# %%
evaluate_model(tuned_qda_pca)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# AI with Shapley values

# %%
et_pca = create_model('et')
# Out:
# <style type="text/css">
# #T_9bd4d_row10_col0, #T_9bd4d_row10_col1, #T_9bd4d_row10_col2, #T_9bd4d_row10_col3, #T_9bd4d_row10_col4, #T_9bd4d_row10_col5, #T_9bd4d_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9bd4d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bd4d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9bd4d_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9bd4d_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9bd4d_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9bd4d_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9bd4d_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9bd4d_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_et_pca = tune_model(et_pca)
# Out:
# <style type="text/css">
# #T_2e83b_row10_col0, #T_2e83b_row10_col1, #T_2e83b_row10_col2, #T_2e83b_row10_col3, #T_2e83b_row10_col4, #T_2e83b_row10_col5, #T_2e83b_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_2e83b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e83b_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2e83b_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2e83b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_2e83b_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_2e83b_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_2e83b_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_2e83b_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_et_pca
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                      class_weight='balanced_subsample', criterion='gini',
#                      max_depth=6, max_features=1.0, max_leaf_nodes=None,
#                      max_samples=None, min_impurity_decrease=0,
#                      min_samples_leaf=4, min_samples_split=7,
#                      min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False)

# %%
evaluate_model(tuned_et_pca)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# !pip install shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 533.5/533.5 kB 5.6 MB/s eta 0:00:00
# ...

# %%
import shap
